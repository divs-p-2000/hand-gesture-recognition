# %%
from google.colab import drive
import glob
import itertools
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
import keras
from keras import layers, metrics

# %%
mount = '/content/gdrive'

drive.mount(mount)

drive_root = mount + '/My Drive/Data Mining Research Paper'

# %cd $drive_root
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Data Mining Research Paper

# %%
no_of_samples = 600
images = []
labels = []
length = 128
width = 128
size = length, width

labels_map = {
    'a': 0,
    'b': 1,
    'c': 2,
    'd': 3,
    'f': 4,
    'g': 5,
}

# %%
for label in labels_map:
  
  temp = 0
  
  for path in glob.glob('Dataset/SL_Muhammad/' + label + '/*.jpg'):
    if temp < no_of_samples:
      img = cv2.imread(path)
      
      grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      inp = cv2.resize(grayscale, size)

      images.append(inp)
      labels.append(labels_map[label])
      temp = temp + 1
  
  print(label)
# Out:
# a
# b
# c
# d
# f
# g

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3)
ax1.imshow(images[no_of_samples * 0 + 1], cmap='gray')
ax1.set(title='A')
ax1.axis('off')
ax2.imshow(images[no_of_samples * 1 + 1], cmap='gray')
ax2.set(title='B')
ax2.axis('off')
ax3.imshow(images[no_of_samples * 2 + 1], cmap='gray')
ax3.set(title='C')
ax3.axis('off')
ax4.imshow(images[no_of_samples * 3 + 1], cmap='gray')
ax4.set(title='D')
ax4.axis('off')
ax5.imshow(images[no_of_samples * 4 + 1], cmap='gray')
ax5.set(title='E')
ax5.axis('off')
ax6.imshow(images[no_of_samples * 5 + 1], cmap='gray')
ax6.set(title='F')
ax6.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
images = np.asarray(images, dtype=np.float32)
images = images/255.0
labels = np.asarray(labels)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size=0.3, random_state=42)
X_train = X_train.reshape(X_train.shape + (1,))
X_test = X_test.reshape(X_test.shape + (1,))

binarizer = LabelBinarizer()
Y_train = binarizer.fit_transform(Y_train)
Y_test = binarizer.fit_transform(Y_test)

# %%
model = keras.models.Sequential()
model.add(layers.Conv2D(32, (5, 5), padding='valid', input_shape=(length,width,1), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
    
model.add(layers.Conv2D(32, 3, 3, padding='valid', activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
  
model.add(layers.Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(6, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      832
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  dropout (Dropout)           (None, 62, 62, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 32)        0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 128)               409728
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 428,454
# Trainable params: 428,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

no_of_epochs = 30
history = model.fit(
    x=X_train, 
    y=Y_train,
    epochs=no_of_epochs,
    validation_data = (X_test, Y_test)
)
# Out:
# Epoch 1/30
# 79/79 [==============================] - 32s 391ms/step - loss: 1.6823 - accuracy: 0.2841 - val_loss: 1.2580 - val_accuracy: 0.5259
# Epoch 2/30
# 79/79 [==============================] - 31s 389ms/step - loss: 1.0116 - accuracy: 0.6433 - val_loss: 0.7463 - val_accuracy: 0.7556
# Epoch 3/30
# 79/79 [==============================] - 31s 388ms/step - loss: 0.6662 - accuracy: 0.7726 - val_loss: 0.5239 - val_accuracy: 0.8111
# Epoch 4/30
# 79/79 [==============================] - 31s 388ms/step - loss: 0.4476 - accuracy: 0.8488 - val_loss: 0.3498 - val_accuracy: 0.8731
# Epoch 5/30
# 79/79 [==============================] - 31s 391ms/step - loss: 0.2996 - accuracy: 0.9000 - val_loss: 0.2264 - val_accuracy: 0.9287
# Epoch 6/30
# 79/79 [==============================] - 31s 390ms/step - loss: 0.1979 - accuracy: 0.9365 - val_loss: 0.2011 - val_accuracy: 0.9361
# Epoch 7/30
# 79/79 [==============================] - 31s 390ms/step - loss: 0.1503 - accuracy: 0.9512 - val_loss: 0.1959 - val_accuracy: 0.9343
# Epoch 8/30
# 79/79 [==============================] - 31s 390ms/step - loss: 0.1122 - accuracy: 0.9587 - val_loss: 0.1721 - val_accuracy: 0.9398
# Epoch 9/30
# 79/79 [==============================] - 31s 390ms/step - loss: 0.1060 - accuracy: 0.9647 - val_loss: 0.1539 - val_accuracy: 0.9574
# Epoch 10/30
# 79/79 [==============================] - 31s 389ms/step - loss: 0.0692 - accuracy: 0.9798 - val_loss: 0.1359 - val_accuracy: 0.9657
# Epoch 11/30
# 79/79 [==============================] - 31s 389ms/step - loss: 0.0693 - accuracy: 0.9794 - val_loss: 0.1547 - val_accuracy: 0.9574
# Epoch 12/30
# 79/79 [==============================] - 31s 388ms/step - loss: 0.0542 - accuracy: 0.9829 - val_loss: 0.1371 - val_accuracy: 0.9556
# Epoch 13/30
# 79/79 [==============================] - 31s 387ms/step - loss: 0.0547 - accuracy: 0.9817 - val_loss: 0.1747 - val_accuracy: 0.9556
# Epoch 14/30
# 79/79 [==============================] - 31s 387ms/step - loss: 0.0596 - accuracy: 0.9817 - val_loss: 0.1362 - val_accuracy: 0.9639
# Epoch 15/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0368 - accuracy: 0.9877 - val_loss: 0.1291 - val_accuracy: 0.9648
# Epoch 16/30
# 79/79 [==============================] - 31s 388ms/step - loss: 0.0313 - accuracy: 0.9873 - val_loss: 0.2060 - val_accuracy: 0.9407
# Epoch 17/30
# 79/79 [==============================] - 30s 384ms/step - loss: 0.0321 - accuracy: 0.9913 - val_loss: 0.1429 - val_accuracy: 0.9583
# Epoch 18/30
# 79/79 [==============================] - 30s 385ms/step - loss: 0.0296 - accuracy: 0.9893 - val_loss: 0.1542 - val_accuracy: 0.9602
# Epoch 19/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0268 - accuracy: 0.9909 - val_loss: 0.1795 - val_accuracy: 0.9519
# Epoch 20/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0325 - accuracy: 0.9897 - val_loss: 0.1319 - val_accuracy: 0.9639
# Epoch 21/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0344 - accuracy: 0.9905 - val_loss: 0.1604 - val_accuracy: 0.9565
# Epoch 22/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0332 - accuracy: 0.9877 - val_loss: 0.1518 - val_accuracy: 0.9574
# Epoch 23/30
# 79/79 [==============================] - 31s 387ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.1372 - val_accuracy: 0.9694
# Epoch 24/30
# 79/79 [==============================] - 31s 387ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.1413 - val_accuracy: 0.9639
# Epoch 25/30
# 79/79 [==============================] - 30s 387ms/step - loss: 0.0198 - accuracy: 0.9925 - val_loss: 0.1463 - val_accuracy: 0.9639
# Epoch 26/30
# 79/79 [==============================] - 30s 385ms/step - loss: 0.0238 - accuracy: 0.9937 - val_loss: 0.1735 - val_accuracy: 0.9667
# Epoch 27/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.1801 - val_accuracy: 0.9611
# Epoch 28/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0186 - accuracy: 0.9933 - val_loss: 0.1380 - val_accuracy: 0.9657
# Epoch 29/30
# 79/79 [==============================] - 39s 493ms/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.1572 - val_accuracy: 0.9602
# Epoch 30/30
# 79/79 [==============================] - 31s 388ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.1395 - val_accuracy: 0.9694

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, no_of_epochs + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Test Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Test Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)
print(classification_report(np.argmax(Y_test, axis=1),
                      np.argmax(y_pred, axis=1),
                      target_names=['a', 'b', 'c', 'd', 'f', 'g']))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.95      0.95      0.95       211
#            b       0.94      0.97      0.95       182
#            c       0.99      0.99      0.99       174
#            d       0.98      0.98      0.98       166
#            f       0.98      0.95      0.97       172
#            g       0.99      0.98      0.98       175
#
#     accuracy                           0.97      1080
#    macro avg       0.97      0.97      0.97      1080
# weighted avg       0.97      0.97      0.97      1080

# %%
conmat = confusion_matrix(np.argmax(Y_test, axis=1),
                      np.argmax(y_pred, axis=1))
plt.imshow(conmat, interpolation='nearest')
plt.title('Confusion Matrix')
ticks = np.arange(6)
plt.xticks(ticks=ticks, labels=['a', 'b', 'c', 'd', 'f', 'g'])
plt.yticks(ticks=ticks, labels=['a', 'b', 'c', 'd', 'f', 'g'])

thresh = conmat.max() / 2
for i, j in itertools.product(range(conmat.shape[0]), range(conmat.shape[1])):
    plt.text(j, i, conmat[i, j],
    horizontalalignment="center",
    color="white" if conmat[i, j] > thresh else "orange")
    
plt.tight_layout()

plt.show()
