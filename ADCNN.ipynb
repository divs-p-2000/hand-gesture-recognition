# %%
from google.colab import drive
import glob
import itertools
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import layers, metrics, regularizers

# %%
mount = '/content/gdrive'

drive.mount(mount)

drive_root = mount + '/My Drive/Data Mining Research Paper'

# %cd $drive_root
# Out:
# Mounted at /content/gdrive
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/Data Mining Research Paper'
# /content

# %%
no_of_samples = 600
images = []
labels = []
length = 128
width = 128
size = length, width

labels_map = {
    'a': 0,
    'b': 1,
    'c': 2,
    'd': 3,
    'f': 4,
    'g': 5,
}

# %%
for label in labels_map:
  
  temp = 0
  
  for path in glob.glob('Dataset/SL_Muhammad/' + label + '/*.jpg'):
    if temp < no_of_samples:
      img = cv2.imread(path)
      
      grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      inp = cv2.resize(grayscale, size)

      images.append(inp)
      labels.append(labels_map[label])
      temp = temp + 1
  
  print(label)
# Out:
# a
# b
# c
# d
# f
# g

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3)
ax1.imshow(images[no_of_samples * 0 + 1], cmap='gray')
ax1.set(title='A')
ax1.axis('off')
ax2.imshow(images[no_of_samples * 1 + 1], cmap='gray')
ax2.set(title='B')
ax2.axis('off')
ax3.imshow(images[no_of_samples * 2 + 1], cmap='gray')
ax3.set(title='C')
ax3.axis('off')
ax4.imshow(images[no_of_samples * 3 + 1], cmap='gray')
ax4.set(title='D')
ax4.axis('off')
ax5.imshow(images[no_of_samples * 4 + 1], cmap='gray')
ax5.set(title='F')
ax5.axis('off')
ax6.imshow(images[no_of_samples * 5 + 1], cmap='gray')
ax6.set(title='G')
ax6.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
images = np.asarray(images, dtype=np.float32)
images = images/255.0
labels = np.asarray(labels)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size=0.3, random_state=42)
X_train = X_train.reshape(X_train.shape + (1,))
X_test = X_test.reshape(X_test.shape + (1,))

binarizer = LabelBinarizer()
Y_train = binarizer.fit_transform(Y_train)
Y_test = binarizer.fit_transform(Y_test)

# %%
l2_param = 0.0001

# %%
model = keras.models.Sequential()
model.add(layers.Conv2D(32, (5, 5), padding='valid', input_shape=(length,width,1), kernel_regularizer=regularizers.l2(l2_param), kernel_initializer='he_uniform', activation='relu'))

model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
    
model.add(layers.Conv2D(32, 3, 3, padding='valid', kernel_regularizer=regularizers.l2(l2_param), kernel_initializer='he_uniform', activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
  
model.add(layers.Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(6, kernel_initializer='glorot_uniform', activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      832
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  dropout (Dropout)           (None, 62, 62, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 32)        0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 128)               409728
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 428,454
# Trainable params: 428,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(
            width_shift_range=0.2, 
            height_shift_range=0.2) 
datagen.fit(X_train)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

no_of_epochs = 30
history = model.fit(
    datagen.flow(X_train, Y_train),
    epochs=no_of_epochs,
    validation_data = (X_test, Y_test)
)
# Out:
# Epoch 1/30
# 79/79 [==============================] - 35s 426ms/step - loss: 1.8234 - accuracy: 0.1754 - val_loss: 1.7930 - val_accuracy: 0.2046
# Epoch 2/30
# 79/79 [==============================] - 34s 426ms/step - loss: 1.7142 - accuracy: 0.2893 - val_loss: 1.5705 - val_accuracy: 0.3676
# Epoch 3/30
# 79/79 [==============================] - 35s 439ms/step - loss: 1.4568 - accuracy: 0.4306 - val_loss: 1.2207 - val_accuracy: 0.5250
# Epoch 4/30
# 79/79 [==============================] - 34s 428ms/step - loss: 1.1969 - accuracy: 0.5679 - val_loss: 0.9875 - val_accuracy: 0.6806
# Epoch 5/30
# 79/79 [==============================] - 35s 439ms/step - loss: 1.0202 - accuracy: 0.6496 - val_loss: 0.8430 - val_accuracy: 0.7250
# Epoch 6/30
# 79/79 [==============================] - 35s 442ms/step - loss: 0.8678 - accuracy: 0.7032 - val_loss: 0.6367 - val_accuracy: 0.8167
# Epoch 7/30
# 79/79 [==============================] - 35s 437ms/step - loss: 0.7801 - accuracy: 0.7361 - val_loss: 0.7204 - val_accuracy: 0.7556
# Epoch 8/30
# 79/79 [==============================] - 35s 438ms/step - loss: 0.6866 - accuracy: 0.7663 - val_loss: 0.4521 - val_accuracy: 0.8722
# Epoch 9/30
# 79/79 [==============================] - 34s 425ms/step - loss: 0.6368 - accuracy: 0.7790 - val_loss: 0.5074 - val_accuracy: 0.8407
# Epoch 10/30
# 79/79 [==============================] - 34s 435ms/step - loss: 0.5560 - accuracy: 0.8095 - val_loss: 0.4617 - val_accuracy: 0.8472
# Epoch 11/30
# 79/79 [==============================] - 34s 429ms/step - loss: 0.5371 - accuracy: 0.8206 - val_loss: 0.3418 - val_accuracy: 0.8991
# Epoch 12/30
# 79/79 [==============================] - 34s 424ms/step - loss: 0.5010 - accuracy: 0.8333 - val_loss: 0.3196 - val_accuracy: 0.8870
# Epoch 13/30
# 79/79 [==============================] - 34s 429ms/step - loss: 0.4767 - accuracy: 0.8524 - val_loss: 0.3073 - val_accuracy: 0.9056
# Epoch 14/30
# 79/79 [==============================] - 33s 423ms/step - loss: 0.4346 - accuracy: 0.8500 - val_loss: 0.2861 - val_accuracy: 0.9056
# Epoch 15/30
# 79/79 [==============================] - 33s 424ms/step - loss: 0.4310 - accuracy: 0.8595 - val_loss: 0.2673 - val_accuracy: 0.9130
# Epoch 16/30
# 79/79 [==============================] - 34s 425ms/step - loss: 0.4178 - accuracy: 0.8639 - val_loss: 0.2681 - val_accuracy: 0.9222
# Epoch 17/30
# 79/79 [==============================] - 34s 424ms/step - loss: 0.4146 - accuracy: 0.8643 - val_loss: 0.2163 - val_accuracy: 0.9213
# Epoch 18/30
# 79/79 [==============================] - 34s 429ms/step - loss: 0.3975 - accuracy: 0.8587 - val_loss: 0.2473 - val_accuracy: 0.9361
# Epoch 19/30
# 79/79 [==============================] - 34s 435ms/step - loss: 0.3691 - accuracy: 0.8710 - val_loss: 0.2306 - val_accuracy: 0.9287
# Epoch 20/30
# 79/79 [==============================] - 34s 424ms/step - loss: 0.3742 - accuracy: 0.8742 - val_loss: 0.2119 - val_accuracy: 0.9315
# Epoch 21/30
# 79/79 [==============================] - 34s 424ms/step - loss: 0.3287 - accuracy: 0.8944 - val_loss: 0.2354 - val_accuracy: 0.9250
# Epoch 22/30
# 79/79 [==============================] - 33s 422ms/step - loss: 0.3547 - accuracy: 0.8794 - val_loss: 0.1906 - val_accuracy: 0.9370
# Epoch 23/30
# 79/79 [==============================] - 33s 424ms/step - loss: 0.3282 - accuracy: 0.8929 - val_loss: 0.1974 - val_accuracy: 0.9296
# Epoch 24/30
# 79/79 [==============================] - 33s 422ms/step - loss: 0.3128 - accuracy: 0.8996 - val_loss: 0.1732 - val_accuracy: 0.9491
# Epoch 25/30
# 79/79 [==============================] - 33s 421ms/step - loss: 0.2862 - accuracy: 0.9151 - val_loss: 0.1985 - val_accuracy: 0.9333
# Epoch 26/30
# 79/79 [==============================] - 33s 421ms/step - loss: 0.2955 - accuracy: 0.9028 - val_loss: 0.1607 - val_accuracy: 0.9454
# Epoch 27/30
# 79/79 [==============================] - 33s 420ms/step - loss: 0.3010 - accuracy: 0.9036 - val_loss: 0.1699 - val_accuracy: 0.9444
# Epoch 28/30
# 79/79 [==============================] - 33s 420ms/step - loss: 0.2944 - accuracy: 0.9044 - val_loss: 0.1507 - val_accuracy: 0.9528
# Epoch 29/30
# 79/79 [==============================] - 33s 419ms/step - loss: 0.2577 - accuracy: 0.9151 - val_loss: 0.1695 - val_accuracy: 0.9454
# Epoch 30/30
# 79/79 [==============================] - 33s 420ms/step - loss: 0.2833 - accuracy: 0.9075 - val_loss: 0.1562 - val_accuracy: 0.9556

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, no_of_epochs + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Test Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Test Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)
print(classification_report(np.argmax(Y_test, axis=1),
                      np.argmax(y_pred, axis=1),
                      target_names=['a', 'b', 'c', 'd', 'f', 'g']))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.95      0.96      0.95       211
#            b       0.95      0.92      0.93       182
#            c       0.99      0.98      0.99       174
#            d       0.93      0.95      0.94       166
#            f       0.93      0.95      0.94       172
#            g       0.98      0.98      0.98       175
#
#     accuracy                           0.96      1080
#    macro avg       0.96      0.96      0.96      1080
# weighted avg       0.96      0.96      0.96      1080

# %%
conmat = confusion_matrix(np.argmax(Y_test, axis=1),
                      np.argmax(y_pred, axis=1))
plt.imshow(conmat, interpolation='nearest')
plt.title('Confusion Matrix')
ticks = np.arange(6)
plt.xticks(ticks=ticks, labels=['a', 'b', 'c', 'd', 'f', 'g'])
plt.yticks(ticks=ticks, labels=['a', 'b', 'c', 'd', 'f', 'g'])

thresh = conmat.max() / 2
for i, j in itertools.product(range(conmat.shape[0]), range(conmat.shape[1])):
    plt.text(j, i, conmat[i, j],
    horizontalalignment="center",
    color="white" if conmat[i, j] > thresh else "orange")
    
plt.tight_layout()

plt.show()
