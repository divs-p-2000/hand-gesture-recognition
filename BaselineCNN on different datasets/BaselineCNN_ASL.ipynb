# %%
from google.colab import drive
import glob
import itertools
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
import keras
from keras import layers, metrics

# %%
mount = '/content/gdrive'

drive.mount(mount)

drive_root = mount + '/My Drive'

# %cd $drive_root
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %%
no_of_samples = 600
images = []
labels = []
length = 128
width = 128
size = length, width

labels_map = {
    'a': 0,
    'b': 1,
    'c': 2,
    'd': 3,
    'e': 4,
    'f': 5,
    }

# %%
for label in labels_map:
  
  temp = 0
  
  for path in glob.glob('Dataset/ASL/' + label + '/*.jpg'):
    if temp < no_of_samples:
      img = cv2.imread(path)
      
      grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      inp = cv2.resize(grayscale, size)

      images.append(inp)
      labels.append(labels_map[label])
      temp = temp + 1
  
  print(label)
# Out:
# a
# b
# c
# d
# e
# f

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3)
ax1.imshow(images[no_of_samples * 0 + 1], cmap='gray')
ax1.set(title='A')
ax1.axis('off')
ax2.imshow(images[no_of_samples * 1 + 1], cmap='gray')
ax2.set(title='B')
ax2.axis('off')
ax3.imshow(images[no_of_samples * 2 + 1], cmap='gray')
ax3.set(title='C')
ax3.axis('off')
ax4.imshow(images[no_of_samples * 3 + 1], cmap='gray')
ax4.set(title='D')
ax4.axis('off')
ax5.imshow(images[no_of_samples * 4 + 1], cmap='gray')
ax5.set(title='E')
ax5.axis('off')
ax6.imshow(images[no_of_samples * 5 + 1], cmap='gray')
ax6.set(title='F')
ax6.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
images = np.asarray(images, dtype=np.float32)
images = images/255.0
labels = np.asarray(labels)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size=0.3, random_state=42)
X_train = X_train.reshape(X_train.shape + (1,))
X_test = X_test.reshape(X_test.shape + (1,))

binarizer = LabelBinarizer()
Y_train = binarizer.fit_transform(Y_train)
Y_test = binarizer.fit_transform(Y_test)

# %%
model = keras.models.Sequential()
model.add(layers.Conv2D(32, (5, 5), padding='valid', input_shape=(length,width,1), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
    
model.add(layers.Conv2D(32, 3, 3, padding='valid', activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
  
model.add(layers.Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(6, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      832
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  dropout (Dropout)           (None, 62, 62, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 32)        0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 128)               409728
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 428,454
# Trainable params: 428,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

no_of_epochs = 30
history = model.fit(
    x=X_train, 
    y=Y_train,
    epochs=no_of_epochs,
    validation_data = (X_test, Y_test)
)
# Out:
# Epoch 1/30
# 79/79 [==============================] - 31s 386ms/step - loss: 1.7884 - accuracy: 0.2040 - val_loss: 1.7461 - val_accuracy: 0.2380
# Epoch 2/30
# 79/79 [==============================] - 31s 392ms/step - loss: 1.5686 - accuracy: 0.3468 - val_loss: 1.3007 - val_accuracy: 0.5130
# Epoch 3/30
# 79/79 [==============================] - 31s 387ms/step - loss: 1.1718 - accuracy: 0.5321 - val_loss: 0.9374 - val_accuracy: 0.6315
# Epoch 4/30
# 79/79 [==============================] - 31s 392ms/step - loss: 0.8286 - accuracy: 0.6778 - val_loss: 0.6892 - val_accuracy: 0.7583
# Epoch 5/30
# 79/79 [==============================] - 30s 384ms/step - loss: 0.6311 - accuracy: 0.7599 - val_loss: 0.5418 - val_accuracy: 0.8167
# Epoch 6/30
# 79/79 [==============================] - 30s 386ms/step - loss: 0.4927 - accuracy: 0.8159 - val_loss: 0.5065 - val_accuracy: 0.8074
# Epoch 7/30
# 79/79 [==============================] - 31s 391ms/step - loss: 0.3882 - accuracy: 0.8579 - val_loss: 0.4083 - val_accuracy: 0.8426
# Epoch 8/30
# 79/79 [==============================] - 30s 385ms/step - loss: 0.3341 - accuracy: 0.8750 - val_loss: 0.3644 - val_accuracy: 0.8546
# Epoch 9/30
# 79/79 [==============================] - 30s 381ms/step - loss: 0.2859 - accuracy: 0.8921 - val_loss: 0.2943 - val_accuracy: 0.8935
# Epoch 10/30
# 79/79 [==============================] - 30s 382ms/step - loss: 0.2408 - accuracy: 0.9159 - val_loss: 0.3766 - val_accuracy: 0.8694
# Epoch 11/30
# 79/79 [==============================] - 30s 382ms/step - loss: 0.2198 - accuracy: 0.9202 - val_loss: 0.2765 - val_accuracy: 0.9028
# Epoch 12/30
# 79/79 [==============================] - 30s 383ms/step - loss: 0.2022 - accuracy: 0.9258 - val_loss: 0.2694 - val_accuracy: 0.9083
# Epoch 13/30
# 79/79 [==============================] - 30s 383ms/step - loss: 0.1546 - accuracy: 0.9460 - val_loss: 0.2779 - val_accuracy: 0.9037
# Epoch 14/30
# 79/79 [==============================] - 34s 426ms/step - loss: 0.1443 - accuracy: 0.9520 - val_loss: 0.2583 - val_accuracy: 0.9065
# Epoch 15/30
# 79/79 [==============================] - 30s 383ms/step - loss: 0.1466 - accuracy: 0.9500 - val_loss: 0.2636 - val_accuracy: 0.9065
# Epoch 16/30
# 79/79 [==============================] - 30s 381ms/step - loss: 0.1479 - accuracy: 0.9540 - val_loss: 0.2380 - val_accuracy: 0.9194
# Epoch 17/30
# 79/79 [==============================] - 30s 384ms/step - loss: 0.1178 - accuracy: 0.9583 - val_loss: 0.2097 - val_accuracy: 0.9315
# Epoch 18/30
# 79/79 [==============================] - 30s 385ms/step - loss: 0.1033 - accuracy: 0.9647 - val_loss: 0.2147 - val_accuracy: 0.9269
# Epoch 19/30
# 79/79 [==============================] - 30s 383ms/step - loss: 0.1008 - accuracy: 0.9659 - val_loss: 0.2153 - val_accuracy: 0.9315
# Epoch 20/30
# 79/79 [==============================] - 30s 383ms/step - loss: 0.0933 - accuracy: 0.9659 - val_loss: 0.2094 - val_accuracy: 0.9269
# Epoch 21/30
# 79/79 [==============================] - 30s 383ms/step - loss: 0.0893 - accuracy: 0.9726 - val_loss: 0.2225 - val_accuracy: 0.9250
# Epoch 22/30
# 79/79 [==============================] - 30s 385ms/step - loss: 0.0795 - accuracy: 0.9730 - val_loss: 0.2297 - val_accuracy: 0.9296
# Epoch 23/30
# 79/79 [==============================] - 30s 384ms/step - loss: 0.0698 - accuracy: 0.9766 - val_loss: 0.2118 - val_accuracy: 0.9370
# Epoch 24/30
# 79/79 [==============================] - 33s 422ms/step - loss: 0.0682 - accuracy: 0.9750 - val_loss: 0.2429 - val_accuracy: 0.9296
# Epoch 25/30
# 79/79 [==============================] - 30s 384ms/step - loss: 0.0616 - accuracy: 0.9762 - val_loss: 0.2423 - val_accuracy: 0.9250
# Epoch 26/30
# 79/79 [==============================] - 39s 492ms/step - loss: 0.0913 - accuracy: 0.9675 - val_loss: 0.2879 - val_accuracy: 0.9194
# Epoch 27/30
# 79/79 [==============================] - 30s 382ms/step - loss: 0.0748 - accuracy: 0.9746 - val_loss: 0.2301 - val_accuracy: 0.9296
# Epoch 28/30
# 79/79 [==============================] - 30s 382ms/step - loss: 0.0538 - accuracy: 0.9825 - val_loss: 0.2429 - val_accuracy: 0.9361
# Epoch 29/30
# 79/79 [==============================] - 31s 388ms/step - loss: 0.0578 - accuracy: 0.9817 - val_loss: 0.2429 - val_accuracy: 0.9398
# Epoch 30/30
# 79/79 [==============================] - 31s 391ms/step - loss: 0.0612 - accuracy: 0.9774 - val_loss: 0.2181 - val_accuracy: 0.9370

# %%
Y_test.size
# Out:
# 6480

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, no_of_epochs + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Test Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Test Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)
print(classification_report(np.argmax(Y_test, axis=1),
                      np.argmax(y_pred, axis=1),
                      target_names=['a', 'b', 'c', 'd', 'e', 'f']))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.90      0.91      0.91       211
#            b       0.93      0.95      0.94       182
#            c       1.00      0.99      1.00       174
#            d       0.94      0.95      0.95       166
#            e       0.89      0.86      0.87       172
#            f       0.97      0.97      0.97       175
#
#     accuracy                           0.94      1080
#    macro avg       0.94      0.94      0.94      1080
# weighted avg       0.94      0.94      0.94      1080

# %%
conmat = confusion_matrix(np.argmax(Y_test, axis=1),
                      np.argmax(y_pred, axis=1))
plt.imshow(conmat, interpolation='nearest')
plt.title('Confusion Matrix')
ticks = np.arange(6)
plt.xticks(ticks=ticks, labels=['a', 'b', 'c', 'd', 'e', 'f'])
plt.yticks(ticks=ticks, labels=['a', 'b', 'c', 'd', 'e', 'f'])

thresh = conmat.max() / 2
for i, j in itertools.product(range(conmat.shape[0]), range(conmat.shape[1])):
    plt.text(j, i, conmat[i, j],
    horizontalalignment="center",
    color="white" if conmat[i, j] > thresh else "orange")
    
plt.tight_layout()

plt.show()
